# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Dataset - Sheet1.csv")

# %%
df
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 1            102    Male   34    Los Angeles          Silver       780.50
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# ..           ...     ...  ...            ...             ...          ...
# 345          446    Male   32          Miami          Silver       660.30
# 346          447  Female   36        Houston          Bronze       470.50
# 347          448  Female   30       New York            Gold      1190.80
# 348          449    Male   34    Los Angeles          Silver       780.20
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               350 non-null    int64
#  1   Gender                    350 non-null    object
#  2   Age                       350 non-null    int64
#  3   City                      350 non-null    object
#  4   Membership Type           350 non-null    object
#  5   Total Spend               350 non-null    float64
#  6   Items Purchased           350 non-null    int64
#  7   Average Rating            350 non-null    float64
#  8   Discount Applied          350 non-null    bool
#  9   Days Since Last Purchase  350 non-null    int64
#  10  Satisfaction Level        348 non-null    object
# dtypes: bool(1), float64(2), int64(4), object(4)
# memory usage: 27.8+ KB

# %%
df.isna().sum()
# Out:
# Customer ID                 0
# Gender                      0
# Age                         0
# City                        0
# Membership Type             0
# Total Spend                 0
# Items Purchased             0
# Average Rating              0
# Discount Applied            0
# Days Since Last Purchase    0
# Satisfaction Level          0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df1=df.copy()

# %%
data_encoded=pd.get_dummies(df1,columns=['Gender','City','Membership Type','Satisfaction Level'])

# %%
data_encoded
# Out:
#      Customer ID  Age  Total Spend  Items Purchased  Average Rating  \
# 0            101   29      1120.20               14             4.6
# 1            102   34       780.50               11             4.1
# 2            103   43       510.75                9             3.4
# 3            104   30      1480.30               19             4.7
# 4            105   27       720.40               13             4.0
# ..           ...  ...          ...              ...             ...
# 345          446   32       660.30               10             3.8
# 346          447   36       470.50                8             3.0
# 347          448   30      1190.80               16             4.5
# 348          449   34       780.20               11             4.2
# 349          450   43       515.75               10             3.3
#
#      Discount Applied  Days Since Last Purchase  Gender_Female  Gender_Male  \
# ...

# %%
data_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 348 entries, 0 to 349
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Customer ID                     348 non-null    int64
#  1   Age                             348 non-null    int64
#  2   Total Spend                     348 non-null    float64
#  3   Items Purchased                 348 non-null    int64
#  4   Average Rating                  348 non-null    float64
#  5   Discount Applied                348 non-null    bool
#  6   Days Since Last Purchase        348 non-null    int64
#  7   Gender_Female                   348 non-null    uint8
#  8   Gender_Male                     348 non-null    uint8
#  9   City_Chicago                    348 non-null    uint8
#  10  City_Houston                    348 non-null    uint8
#  11  City_Los Angeles                348 non-null    uint8
# ...

# %%
#Segmentation on the basis of gender:
segmentation_on_gender=['Gender']
segmented_d1=df1.groupby(segmentation_on_gender).size().reset_index(name='Count')

# %%
segmented_d1
# Out:
#    Gender  Count
# 0  Female    173
# 1    Male    175

# %%
#segmentation on the basis of age:
segmentation_by_age=['Age']
segmented_df2=df1.groupby(segmentation_by_age).size().reset_index(name='Count')

# %%
segmented_df2
# Out:
#     Age  Count
# 0    26      9
# 1    27     25
# 2    28     24
# 3    29     11
# 4    30     48
# 5    31     25
# 6    32     33
# 7    33     10
# 8    34     24
# 9    35     25
# 10   36     25
# 11   37     22
# 12   38      9
# 13   41     24
# 14   42      9
# 15   43     25

# %%
#segmentation on the basis of membership type:
segmentation_by_membership_type=['Membership Type']
segmented_d3=df1.groupby(segmentation_by_membership_type).size().reset_index(name='Count')

# %%
segmented_d3
# Out:
#   Membership Type  Count
# 0          Bronze    114
# 1            Gold    117
# 2          Silver    117

# %%
#segmentation on the basis of city:
segmentation_by_location=['City']
segmented_d4=df1.groupby(segmentation_by_location).size().reset_index(name='Count')

# %%
segmented_d4
# Out:
#             City  Count
# 0        Chicago     58
# 1        Houston     56
# 2    Los Angeles     59
# 3          Miami     58
# 4       New York     59
# 5  San Francisco     58

# %%
# Visualization by Gender:

# %%
#Total amount spend(gender wise):
Total_spend_by_gender=df1.groupby('Gender')['Total Spend'].sum().reset_index()
Total_spend_by_gender
# Out:
#    Gender  Total Spend
# 0  Female     122318.4
# 1    Male     172713.6

# %%
#Visualization in bar plot:
plt.figure(figsize=(10,6))
plt.bar(Total_spend_by_gender['Gender'],Total_spend_by_gender['Total Spend'],color=['violet','red'])
plt.title('Total_spend_by_gender')
plt.xlabel('Gender')
plt.ylabel('Total Spend')
plt.show()

# %%
#Total amount spend on items(gender wise)
items_purchased_by_gender=df.groupby('Gender')['Items Purchased'].sum().reset_index()
items_purchased_by_gender
# Out:
#    Gender  Items Purchased
# 0  Female             1869
# 1    Male             2527

# %%
#Visualization in bar plot:
sns.catplot(x='Gender',y='Items Purchased',kind='bar',data=df1,palette='viridis')
plt.title('Number Of Items Purchased By Gender')
plt.xlabel('Gender')
plt.ylabel('Item Purchased')
plt.show()

# %%
# Calculate average sattisfaction levels:
satisfaction_mapping={'Satisfied':3, 'Neutral':2, 'Unsatisfied':1}

df1['Satisfaction Scores']=df1['Satisfaction Level'].map(satisfaction_mapping)
df2=df1.copy()
df2
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 1            102    Male   34    Los Angeles          Silver       780.50
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# ..           ...     ...  ...            ...             ...          ...
# 345          446    Male   32          Miami          Silver       660.30
# 346          447  Female   36        Houston          Bronze       470.50
# 347          448  Female   30       New York            Gold      1190.80
# 348          449    Male   34    Los Angeles          Silver       780.20
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
#Gender wise average satisfaction levels:
avg_satisfaction_by_gender=df2.groupby('Gender')['Satisfaction Scores'].mean().reset_index()
avg_satisfaction_by_gender
# Out:
#    Gender  Satisfaction Scores
# 0  Female             1.994220
# 1    Male             2.057143

# %%
#Graphical representation of gender wise average satisfaction levels:
sns.catplot(x='Gender',y='Satisfaction Scores',kind='bar',data=avg_satisfaction_by_gender)
plt.title('Average Satisfaction Score by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Satisfaction Score')
plt.show()

# %%
# Visualization by Age

# %%
#Total amount spend(age wise):
Total_Spend_By_Age=df.groupby('Age')['Total Spend'].sum().reset_index()
Total_Spend_By_Age
# Out:
#     Age  Total Spend
# 0    26      6205.40
# 1    27     17770.50
# 2    28     35812.40
# 3    29     14192.40
# 4    30     63631.00
# 5    31     28615.00
# 6    32     26579.90
# 7    33      8206.40
# 8    34     18985.10
# 9    35     20002.20
# 10   36     12522.80
# 11   37      9517.60
# 12   38      3998.10
# 13   41     11626.00
# 14   42      4668.45
# 15   43     12698.75

# %%
#graphical representation of total amount spend(age wise):
plt.figure(figsize=(10,6))
plt.pie(Total_Spend_By_Age['Total Spend'],labels=Total_Spend_By_Age['Age'],autopct='%1.1f%%')
plt.title('Total Spend By Age')
plt.show()

# %%
#Total spend on items by age:
items_purchased_by_age=df.groupby('Age')['Items Purchased'].sum().reset_index()
items_purchased_by_age
# Out:
#     Age  Items Purchased
# 0    26              108
# 1    27              323
# 2    28              504
# 3    29              190
# 4    30              859
# 5    31              377
# 6    32              367
# 7    33              126
# 8    34              264
# 9    35              295
# 10   36              210
# 11   37              155
# 12   38               72
# 13   41              217
# 14   42               82
# 15   43              247

# %%
#Graphical representation of Total spend on items by age(line graph):
plt.figure(figsize=(10,6))
plt.plot(items_purchased_by_age['Age'],items_purchased_by_age['Items Purchased'],color='blue')
plt.title('Items Purchased By Age')
plt.xlabel('Age')
plt.ylabel('Items Purchased')
plt.show()

# %%
#Membership type by age:
membership_by_age=df1.groupby(['Age','Membership Type']).size().unstack().fillna(0)
membership_by_age
# Out:
# Membership Type  Bronze  Gold  Silver
# Age
# 26                  0.0   0.0     9.0
# 27                  0.0   0.0    25.0
# 28                  0.0  24.0     0.0
# 29                  0.0  10.0     1.0
# 30                  0.0  48.0     0.0
# 31                  0.0  25.0     0.0
# 32                  0.0   9.0    24.0
# 33                  0.0   0.0    10.0
# 34                  0.0   0.0    24.0
# 35                  1.0   0.0    24.0
# 36                 24.0   1.0     0.0
# 37                 22.0   0.0     0.0
# 38                  9.0   0.0     0.0
# 41                 24.0   0.0     0.0
# 42                  9.0   0.0     0.0
# 43                 25.0   0.0     0.0

# %%
#Graphical representation of membership type by age:
membership_by_age.plot(kind='bar',stacked=True, figsize=(10,6),color=['yellow','blue','red'])
plt.title('Membership Type Distribution by Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend(title='Membership Type')
plt.show()

# %%
# Customers based on membership type:
customer_count_by_membership=df1['Membership Type'].value_counts().reset_index()
customer_count_by_membership.columns=['Membership Type','Customer Count']
customer_count_by_membership
# Out:
#   Membership Type  Customer Count
# 0            Gold             117
# 1          Silver             117
# 2          Bronze             114

# %%
#Average satisfaction level by age:
avg_satisfaction_by_age=df2.groupby('Age')['Satisfaction Scores'].mean().reset_index()
avg_satisfaction_by_age
# Out:
#     Age  Satisfaction Scores
# 0    26             1.000000
# 1    27             1.040000
# 2    28             3.000000
# 3    29             2.818182
# 4    30             3.000000
# 5    31             3.000000
# 6    32             1.545455
# 7    33             2.800000
# 8    34             2.000000
# 9    35             2.000000
# 10   36             2.040000
# 11   37             2.000000
# 12   38             2.000000
# 13   41             1.000000
# 14   42             1.000000
# 15   43             1.000000

# %%
#Graphical representation of average satisfaction level by age:
plt.figure(figsize=(10,6))
plt.bar(avg_satisfaction_by_age['Age'],avg_satisfaction_by_age['Satisfaction Scores'],color='purple')
plt.title('Avg Satisfaction Score by Age')
plt.xlabel('Age')
plt.ylabel('Avg Satisfaction Score')
plt.show()

# %%
# Visualization by membership type

# %%
#Membership type wise total spend:
Total_spend_by_membership=df2.groupby('Membership Type')['Total Spend'].sum().reset_index()
Total_spend_by_membership
# Out:
#   Membership Type  Total Spend
# 0          Bronze      54061.5
# 1            Gold     153403.9
# 2          Silver      87566.6

# %%
#Graphical representation of membership type wise total spend:
plt.figure(figsize=(10,6))
plt.bar(Total_spend_by_membership['Membership Type'],Total_spend_by_membership['Total Spend'],color=['red','orange','brown'])
plt.title('Total Spending By Membership Type')
plt.xlabel('Membership Type')
plt.ylabel('Total Spend')
plt.show()

# %%
# Total spend on items by membership type:
Total_items_by_membership=df1.groupby('Membership Type')['Items Purchased'].sum().reset_index()
Total_items_by_membership
# Out:
#   Membership Type  Items Purchased
# 0          Bronze              971
# 1            Gold             2061
# 2          Silver             1364

# %%
#Graphical representation of total spend on items by membership type:
plt.figure(figsize=(10,6))
plt.plot(Total_items_by_membership['Membership Type'],Total_items_by_membership['Items Purchased'],color='#DA2C3F')
plt.title('Total items Purchased by Membership Type')
plt.xlabel('Membership Type')
plt.ylabel('Total Items Purchased')
plt.show()

# %%
#Membership wise average satisfaction level:
Avg_satisfaction_by_membership=df2.groupby('Membership Type')['Satisfaction Scores'].mean().reset_index()
Avg_satisfaction_by_membership
# Out:
#   Membership Type  Satisfaction Scores
# 0          Bronze             1.491228
# 1            Gold             3.000000
# 2          Silver             1.572650

# %%
#Graphical representation of membership wise average satisfaction level:
plt.figure(figsize=(10,6))
plt.bar(Avg_satisfaction_by_membership['Membership Type'],Avg_satisfaction_by_membership['Satisfaction Scores'],color=['green','blue','gold'])
plt.title('Average Satisfaction Score By Membership Type')
plt.xlabel('Membership Type')
plt.ylabel('Average Satisfaction Score')
plt.show()

# %%
# Visualization by City

# %%
#City wise total spend:
Total_spend_by_city=df1.groupby('City')['Total Spend'].sum().reset_index()
Total_spend_by_city
# Out:
#             City  Total Spend
# 0        Chicago      28993.2
# 1        Houston      25919.9
# 2    Los Angeles      47524.0
# 3          Miami      40042.6
# 4       New York      68737.1
# 5  San Francisco      84666.8

# %%
#Graphical representation of city wise total spend:
sns.displot(data=df1,x="Total Spend",kind="kde",hue="City",alpha=0.3)

# %%
# Total spend on items by city:
Total_items_purchased_by_city=df1.groupby('City')['Items Purchased'].sum().reset_index()
Total_items_purchased_by_city
# Out:
#             City  Items Purchased
# 0        Chicago              546
# 1        Houston              439
# 2    Los Angeles              689
# 3          Miami              675
# 4       New York              901
# 5  San Francisco             1160

# %%
#Graphical representation of total spend on items by city:
plt.figure(figsize=(10,6))
plt.bar(Total_items_purchased_by_city['City'],Total_items_purchased_by_city['Items Purchased'],color=['violet','blue','silver'])
plt.title('City Wise Total Items')
plt.xlabel('City')
plt.ylabel('Items Purchased')
plt.show()

# %%
#City wise average satisfaction level:
City_wise_average_satisfaction_level=df2.groupby('City')['Satisfaction Scores'].mean().reset_index()
City_wise_average_satisfaction_level
# Out:
#             City  Satisfaction Scores
# 0        Chicago             1.000000
# 1        Houston             2.000000
# 2    Los Angeles             2.135593
# 3          Miami             1.000000
# 4       New York             3.000000
# 5  San Francisco             3.000000

# %%
#Graphical representation of city wise average satisfaction level:
plt.figure(figsize=(10,6))
plt.bar(City_wise_average_satisfaction_level['City'],City_wise_average_satisfaction_level['Satisfaction Scores'],color=['violet','blue','silver'])
plt.title('City Wise Average Satisfaction Level')
plt.xlabel('City')
plt.ylabel('Satisfaction Scores')
plt.show()

# %%
Discount_mapping={True:2, False:1}

df1['Discount Scores']=df1['Discount Applied'].map(Discount_mapping)
df3=df1.copy()
df3
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 1            102    Male   34    Los Angeles          Silver       780.50
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# ..           ...     ...  ...            ...             ...          ...
# 345          446    Male   32          Miami          Silver       660.30
# 346          447  Female   36        Houston          Bronze       470.50
# 347          448  Female   30       New York            Gold      1190.80
# 348          449    Male   34    Los Angeles          Silver       780.20
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %%
plt.bar(df3['Discount Scores'],df3['Days Since Last Purchase'],color=['blue','green'])
plt.title('Discount vs Days Since Last Purchase')
plt.xlabel('Discount')
plt.ylabel('Days')
plt.show()
